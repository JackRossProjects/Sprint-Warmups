# %% [markdown]
# _Lambda School Data Science, Unit 2_
#
# # Sprint Challenge: Predict Steph Curry's shots 🏀
#
# For your Sprint Challenge, you'll use a dataset with all Steph Curry's NBA field goal attempts. (Regular season and playoff games, from October 28, 2009, through June 5, 2019.)
#
# You'll predict whether each shot was made, using information about the shot and the game. This is hard to predict! Try to get above 60% accuracy. The dataset was collected with the [nba_api](https://github.com/swar/nba_api) Python library.

# %%
# %%capture
import sys

if 'google.colab' in sys.modules:
    # Install packages in Colab
    # !pip install category_encoders==2.*
    # !pip install pandas-profiling==2.*

# %%
# %matplotlib inline
import category_encoders as ce
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.decomposition import PCA
from sklearn.decomposition import FactorAnalysis
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import RobustScaler

# %%
# Read data
import pandas as pd
url = 'https://drive.google.com/uc?export=download&id=1fL7KPyxgGYfQDsuJoBWHIWwCAf-HTFpX'
df = pd.read_csv(url)

# Check data shape
assert df.shape == (13958, 20)

# %% [markdown]
# To demonstrate mastery on your Sprint Challenge, do all the required, numbered instructions in this notebook.
#
# To earn a score of "3", also do all the stretch goals.
#
# You are permitted and encouraged to do as much data exploration as you want.
#
# **1. Begin with baselines for classification.** Your target to predict is `shot_made_flag`. What is your baseline accuracy, if you guessed the majority class for every prediction?
#
# **2. Hold out your test set.** Use the 2018-19 season to test. NBA seasons begin in October and end in June. You'll know you've split the data correctly when your test set has 1,709 observations.
#
# **3. Engineer new feature.** Engineer at least **1** new feature, from this list, or your own idea.
# - **Homecourt Advantage**: Is the home team (`htm`) the Golden State Warriors (`GSW`) ?
# - **Opponent**: Who is the other team playing the Golden State Warriors?
# - **Seconds remaining in the period**: Combine minutes remaining with seconds remaining, to get the total number of seconds remaining in the period.
# - **Seconds remaining in the game**: Combine period, and seconds remaining in the period, to get the total number of seconds remaining in the game. A basketball game has 4 periods, each 12 minutes long.
# - **Made previous shot**: Was Steph Curry's previous shot successful?
#
# **4. Decide how to validate** your model. Choose one of the following options. Any of these options are good. You are not graded on which you choose.
# - **Train/validate/test split: train on the 2009-10 season through 2016-17 season, validate with the 2017-18 season.** You'll know you've split the data correctly when your train set has 11,081 observations, and your validation set has 1,168 observations.
# - **Train/validate/test split: random 80/20%** train/validate split.
# - **Cross-validation** with independent test set. You may use any scikit-learn cross-validation method.
#
# **5.** Use a scikit-learn **pipeline** to **encode categoricals** and fit a **Decision Tree** or **Random Forest** model.
#
# **6.** Get your model's **validation accuracy.** (Multiple times if you try multiple iterations.)
#
# **7.** Get your model's **test accuracy.** (One time, at the end.)
#
#
# **8.** Given a **confusion matrix** for a hypothetical binary classification model, **calculate accuracy, precision, and recall.**
#
# ### Stretch Goals
# - Engineer 4+ new features total, either from the list above, or your own ideas.
# - Make 2+ visualizations to explore relationships between features and target.
# - Optimize 3+ hyperparameters by trying 10+ "candidates" (possible combinations of hyperparameters). You can use `RandomizedSearchCV` or do it manually.
# - Get and plot your model's feature importances.

# %% [markdown]
# ## 1. Begin with baselines for classification.
#
# >Your target to predict is `shot_made_flag`. What would your baseline accuracy be, if you guessed the majority class for every prediction?

# %%
target = df['shot_made_flag']
majority_value = target.mode()[0]
majority_value
# Out:
# 0

# %%
from sklearn.metrics import accuracy_score

y_pred = [majority_value] * len(df)
train_acc = accuracy_score(target, y_pred)
print(f'The training majority baseline is {train_acc*100:.02f}%')
# Out:
# The training majority baseline is 52.71%

# %% [markdown]
# ## 2. Hold out your test set.
#
# >Use the 2018-19 season to test. NBA seasons begin in October and end in June. You'll know you've split the data correctly when your test set has 1,709 observations.

# %%
mask = (df['game_date'] > '2018-10-1') & (df['game_date'] <= '2019-6-31')

# %%
test = df.loc[mask]
test
# Out:
#         game_id  game_event_id    player_name  period  minutes_remaining  \
# 12249  21800002             10  Stephen Curry       1                 11
# 12250  21800002             58  Stephen Curry       1                  7
# 12251  21800002            131  Stephen Curry       1                  3
# 12252  21800002            141  Stephen Curry       1                  2
# 12253  21800002            145  Stephen Curry       1                  2
# ...         ...            ...            ...     ...                ...
# 13953  41800403            570  Stephen Curry       4                  8
# 13954  41800403            573  Stephen Curry       4                  7
# 13955  41800403            602  Stephen Curry       4                  5
# 13956  41800403            608  Stephen Curry       4                  4
# 13957  41800403            658  Stephen Curry       4                  2
#
#        seconds_remaining                 action_type       shot_type  \
# 12249                 31         Step Back Jump shot  3PT Field Goal
# 12250                 57  Driving Floating Jump Shot  2PT Field Goal
# 12251                 46          Driving Layup Shot  2PT Field Goal
# 12252                 58  Driving Reverse Layup Shot  2PT Field Goal
# 12253                 49                   Jump Shot  3PT Field Goal
# ...                  ...                         ...             ...
# 13953                  1            Pullup Jump shot  2PT Field Goal
# 13954                 16          Floating Jump shot  2PT Field Goal
# 13955                 27         Step Back Jump shot  3PT Field Goal
# 13956                 50  Driving Floating Jump Shot  2PT Field Goal
# 13957                 47                   Jump Shot  3PT Field Goal
#
#              shot_zone_basic         shot_zone_area  shot_zone_range  \
# 12249      Above the Break 3  Right Side Center(RC)          24+ ft.
# 12250  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 12251        Restricted Area              Center(C)  Less Than 8 ft.
# 12252        Restricted Area              Center(C)  Less Than 8 ft.
# 12253          Left Corner 3           Left Side(L)          24+ ft.
# ...                      ...                    ...              ...
# 13953  In The Paint (Non-RA)              Center(C)         8-16 ft.
# 13954              Mid-Range          Right Side(R)         8-16 ft.
# 13955      Above the Break 3   Left Side Center(LC)          24+ ft.
# 13956  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 13957      Above the Break 3   Left Side Center(LC)          24+ ft.
#
#        shot_distance  loc_x  loc_y  shot_made_flag   game_date  htm  vtm  \
# 12249             24    226     90               1  2018-10-16  GSW  OKC
# 12250              6     -2     63               1  2018-10-16  GSW  OKC
# 12251              2      5     29               1  2018-10-16  GSW  OKC
# 12252              1     -6     18               0  2018-10-16  GSW  OKC
# 12253             22   -228      8               1  2018-10-16  GSW  OKC
# ...              ...    ...    ...             ...         ...  ...  ...
# 13953             12      3    120               1  2019-06-05  GSW  TOR
# 13954             11    114     -5               0  2019-06-05  GSW  TOR
# 13955             26   -217    149               0  2019-06-05  GSW  TOR
# 13956              7     59     49               0  2019-06-05  GSW  TOR
# 13957             24   -226    104               0  2019-06-05  GSW  TOR
#
#           season_type  scoremargin_before_shot
# 12249  Regular Season                      0.0
# 12250  Regular Season                      4.0
# 12251  Regular Season                      4.0
# 12252  Regular Season                      7.0
# 12253  Regular Season                      7.0
# ...               ...                      ...
# 13953        Playoffs                    -13.0
# 13954        Playoffs                    -14.0
# 13955        Playoffs                    -17.0
# 13956        Playoffs                    -16.0
# 13957        Playoffs                    -12.0
#
# [1709 rows x 20 columns]

# %%
train = df[~mask]

# %%
train
# Out:
#         game_id  game_event_id    player_name  period  minutes_remaining  \
# 0      20900015              4  Stephen Curry       1                 11
# 1      20900015             17  Stephen Curry       1                  9
# 2      20900015             53  Stephen Curry       1                  6
# 3      20900015            141  Stephen Curry       2                  9
# 4      20900015            249  Stephen Curry       2                  2
# ...         ...            ...            ...     ...                ...
# 12244  41700404            582  Stephen Curry       4                  6
# 12245  41700404            588  Stephen Curry       4                  5
# 12246  41700404            591  Stephen Curry       4                  5
# 12247  41700404            603  Stephen Curry       4                  4
# 12248  41700404            614  Stephen Curry       4                  3
#
#        seconds_remaining                 action_type       shot_type  \
# 0                     25                   Jump Shot  3PT Field Goal
# 1                     31         Step Back Jump shot  2PT Field Goal
# 2                      2                   Jump Shot  2PT Field Goal
# 3                     49                   Jump Shot  2PT Field Goal
# 4                     19                   Jump Shot  2PT Field Goal
# ...                  ...                         ...             ...
# 12244                 19                   Jump Shot  3PT Field Goal
# 12245                 48  Driving Floating Jump Shot  2PT Field Goal
# 12246                 13                   Jump Shot  3PT Field Goal
# 12247                 27          Cutting Layup Shot  2PT Field Goal
# 12248                 49          Driving Layup Shot  2PT Field Goal
#
#              shot_zone_basic         shot_zone_area  shot_zone_range  \
# 0          Above the Break 3  Right Side Center(RC)          24+ ft.
# 1                  Mid-Range   Left Side Center(LC)        16-24 ft.
# 2      In The Paint (Non-RA)              Center(C)         8-16 ft.
# 3                  Mid-Range           Left Side(L)        16-24 ft.
# 4                  Mid-Range   Left Side Center(LC)        16-24 ft.
# ...                      ...                    ...              ...
# 12244          Left Corner 3           Left Side(L)          24+ ft.
# 12245              Mid-Range           Left Side(L)         8-16 ft.
# 12246      Above the Break 3   Left Side Center(LC)          24+ ft.
# 12247        Restricted Area              Center(C)  Less Than 8 ft.
# 12248  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
#
#        shot_distance  loc_x  loc_y  shot_made_flag   game_date  htm  vtm  \
# 0                 26     99    249               0  2009-10-28  GSW  HOU
# 1                 18   -122    145               1  2009-10-28  GSW  HOU
# 2                 14    -60    129               0  2009-10-28  GSW  HOU
# 3                 19   -172     82               0  2009-10-28  GSW  HOU
# 4                 16    -68    148               0  2009-10-28  GSW  HOU
# ...              ...    ...    ...             ...         ...  ...  ...
# 12244             24   -240      0               1  2018-06-08  CLE  GSW
# 12245             14   -115     89               0  2018-06-08  CLE  GSW
# 12246             34   -116    330               0  2018-06-08  CLE  GSW
# 12247              1     14     11               0  2018-06-08  CLE  GSW
# 12248              6     13     59               0  2018-06-08  CLE  GSW
#
#           season_type  scoremargin_before_shot
# 0      Regular Season                      2.0
# 1      Regular Season                      0.0
# 2      Regular Season                     -4.0
# 3      Regular Season                     -4.0
# 4      Regular Season                      0.0
# ...               ...                      ...
# 12244        Playoffs                     25.0
# 12245        Playoffs                     28.0
# 12246        Playoffs                     26.0
# 12247        Playoffs                     25.0
# 12248        Playoffs                     25.0
#
# [12249 rows x 20 columns]

# %% [markdown]
# ## 3. Engineer new feature.
#
# >Engineer at least **1** new feature, from this list, or your own idea.
# >
# >- **Homecourt Advantage**: Is the home team (`htm`) the Golden State Warriors (`GSW`) ?
# >- **Opponent**: Who is the other team playing the Golden State Warriors?
# >- **Seconds remaining in the period**: Combine minutes remaining with seconds remaining, to get the total number of seconds remaining in the period.
# >- **Seconds remaining in the game**: Combine period, and seconds remaining in the period, to get the total number of seconds remaining in the game. A basketball game has 4 periods, each 12 minutes long.
# >- **Made previous shot**: Was Steph Curry's previous shot successful?

# %%
train['seconds_in_period_remaining'] = (train['minutes_remaining'] * 60) + train['seconds_remaining']
test['seconds_in_period_remaining'] = (test['minutes_remaining'] * 60) + test['seconds_remaining']
# Out:
# /home/jack/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/jack/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test['seconds_in_period_remaining']
# Out:
# 12249    691
# 12250    477
# 12251    226
# 12252    178
# 12253    169
#         ...
# 13953    481
# 13954    436
# 13955    327
# 13956    290
# 13957    167
# Name: seconds_in_period_remaining, Length: 1709, dtype: int64

# %% [markdown]
# ## **4. Decide how to validate** your model.
#
# >Choose one of the following options. Any of these options are good. You are not graded on which you choose.
# >
# >- **Train/validate/test split: train on the 2009-10 season through 2016-17 season, validate with the 2017-18 season.** You'll know you've split the data correctly when your train set has 11,081 observations, and your validation set has 1,168 observations.
# >- **Train/validate/test split: random 80/20%** train/validate split.
# >- **Cross-validation** with independent test set. You may use any scikit-learn cross-validation method.

# %%
train, val = train_test_split(train, train_size= 0.861, random_state=42)

# %%
train
# Out:
#         game_id  game_event_id    player_name  period  minutes_remaining  \
# 5147   21300899             26  Stephen Curry       1                  9
# 9004   41500144             19  Stephen Curry       1                  9
# 7825   21500300            250  Stephen Curry       2                  2
# 7738   21500236            123  Stephen Curry       1                  0
# 3884   41200161            190  Stephen Curry       2                  7
# ...         ...            ...            ...     ...                ...
# 11964  41700233            112  Stephen Curry       1                  2
# 5191   21300942            289  Stephen Curry       3                  8
# 5390   21301141            372  Stephen Curry       3                  2
# 860    20900982            295  Stephen Curry       3                  9
# 7270   41400315            557  Stephen Curry       4                  2
#
#        seconds_remaining                 action_type       shot_type  \
# 5147                  24                   Jump Shot  2PT Field Goal
# 9004                  45                   Jump Shot  3PT Field Goal
# 7825                  45          Floating Jump shot  2PT Field Goal
# 7738                   3  Driving Reverse Layup Shot  2PT Field Goal
# 3884                  19                   Jump Shot  2PT Field Goal
# ...                  ...                         ...             ...
# 11964                 32                   Jump Shot  3PT Field Goal
# 5191                  42            Pullup Jump shot  3PT Field Goal
# 5390                  45            Pullup Jump shot  2PT Field Goal
# 860                   35                   Jump Shot  3PT Field Goal
# 7270                  59            Pullup Jump shot  3PT Field Goal
#
#          shot_zone_basic         shot_zone_area  ... shot_distance  loc_x  \
# 5147           Mid-Range  Right Side Center(RC)  ...            22    174
# 9004   Above the Break 3  Right Side Center(RC)  ...            25    159
# 7825           Mid-Range          Right Side(R)  ...            15     84
# 7738     Restricted Area              Center(C)  ...             1    -17
# 3884           Mid-Range              Center(C)  ...            17    -34
# ...                  ...                    ...  ...           ...    ...
# 11964  Above the Break 3              Center(C)  ...            25    -16
# 5191   Above the Break 3              Center(C)  ...            25    -18
# 5390           Mid-Range   Left Side Center(LC)  ...            18   -128
# 860        Left Corner 3           Left Side(L)  ...            22   -228
# 7270   Above the Break 3              Center(C)  ...            27    -16
#
#        loc_y  shot_made_flag   game_date  htm  vtm     season_type  \
# 5147     138               0  2014-03-04  IND  GSW  Regular Season
# 9004     203               0  2016-04-24  HOU  GSW        Playoffs
# 7825     129               1  2015-12-06  BKN  GSW  Regular Season
# 7738      -1               0  2015-11-27  PHX  GSW  Regular Season
# 3884     168               0  2013-04-20  DEN  GSW        Playoffs
# ...      ...             ...         ...  ...  ...             ...
# 11964    258               0  2018-05-04  NOP  GSW        Playoffs
# 5191     254               0  2014-03-09  GSW  PHX  Regular Season
# 5390     132               0  2014-04-04  GSW  SAC  Regular Season
# 860       20               1  2010-03-13  GSW  TOR  Regular Season
# 7270     274               0  2015-05-27  GSW  HOU        Playoffs
#
#       scoremargin_before_shot  seconds_in_period_remaining
# 5147                     -2.0                          564
# 9004                     -1.0                          585
# 7825                      9.0                          165
# 7738                     17.0                            3
# 3884                      4.0                          439
# ...                       ...                          ...
# 11964                   -13.0                          152
# 5191                     -1.0                          522
# 5390                     33.0                          165
# 860                       3.0                          575
# 7270                     13.0                          179
#
# [10546 rows x 21 columns]

# %%
val
# Out:
#        game_id  game_event_id    player_name  period  minutes_remaining  \
# 5026  21300788            375  Stephen Curry       3                  0
# 6676  21400999              2  Stephen Curry       1                 11
# 9794  21600405             84  Stephen Curry       1                  3
# 5577  41300166             57  Stephen Curry       1                  6
# 9399  21600054            405  Stephen Curry       3                  1
# ...        ...            ...            ...     ...                ...
# 2536  21200036            503  Stephen Curry       3                  0
# 6504  21400838             81  Stephen Curry       1                  4
# 4189  21300091            197  Stephen Curry       2                  5
# 3422  21200853            491  Stephen Curry       4                  3
# 2818  21200299            344  Stephen Curry       3                  5
#
#       seconds_remaining          action_type       shot_type  \
# 5026                  1  Step Back Jump shot  3PT Field Goal
# 6676                 44  Step Back Jump shot  2PT Field Goal
# 9794                 20   Cutting Layup Shot  2PT Field Goal
# 5577                  5   Driving Layup Shot  2PT Field Goal
# 9399                 11     Pullup Jump shot  2PT Field Goal
# ...                 ...                  ...             ...
# 2536                 59            Jump Shot  3PT Field Goal
# 6504                 42     Pullup Jump shot  2PT Field Goal
# 4189                 25            Jump Shot  3PT Field Goal
# 3422                 42            Jump Shot  3PT Field Goal
# 2818                 34            Jump Shot  3PT Field Goal
#
#         shot_zone_basic         shot_zone_area  ... shot_distance  loc_x  \
# 5026  Above the Break 3              Center(C)  ...            25      0
# 6676          Mid-Range  Right Side Center(RC)  ...            22     99
# 9794    Restricted Area              Center(C)  ...             2     -1
# 5577    Restricted Area              Center(C)  ...             1     13
# 9399          Mid-Range  Right Side Center(RC)  ...            22    102
# ...                 ...                    ...  ...           ...    ...
# 2536  Above the Break 3  Right Side Center(RC)  ...            26    143
# 6504          Mid-Range   Left Side Center(LC)  ...            18   -116
# 4189     Right Corner 3          Right Side(R)  ...            23    231
# 3422  Above the Break 3  Right Side Center(RC)  ...            24    207
# 2818      Left Corner 3           Left Side(L)  ...            24   -242
#
#       loc_y  shot_made_flag   game_date  htm  vtm     season_type  \
# 5026    254               1  2014-02-12  GSW  MIA  Regular Season
# 6676    203               0  2015-03-16  GSW  LAL  Regular Season
# 9794     23               1  2016-12-17  GSW  POR  Regular Season
# 5577     12               1  2014-05-01  GSW  LAC        Playoffs
# 9399    198               0  2016-11-01  POR  GSW  Regular Season
# ...     ...             ...         ...  ...  ...             ...
# 2536    227               0  2012-11-03  LAC  GSW  Regular Season
# 6504    142               1  2015-02-24  WAS  GSW  Regular Season
# 4189    -13               1  2013-11-09  MEM  GSW  Regular Season
# 3422    140               1  2013-02-27  NYK  GSW  Regular Season
# 2818      3               1  2012-12-10  CHA  GSW  Regular Season
#
#      scoremargin_before_shot  seconds_in_period_remaining
# 5026                    -5.0                            1
# 6676                     0.0                          704
# 9794                     9.0                          200
# 5577                    -7.0                          365
# 9399                    23.0                           71
# ...                      ...                          ...
# 2536                     6.0                           59
# 6504                    -5.0                          282
# 4189                    -8.0                          325
# 3422                    -2.0                          222
# 2818                    13.0                          334
#
# [1703 rows x 21 columns]

# %% [markdown]
# ## 5. Use a scikit-learn pipeline to encode categoricals and fit a Decision Tree or Random Forest model.

# %%
target = 'shot_made_flag'
train, val = train_test_split(train, test_size=len(test),  
                              stratify=train[target], random_state=42)



# Arrange data into X features matrix and y target vector
X_train = train.drop(columns=target)
y_train = train[target]
X_val = val.drop(columns=target)
y_val = val[target]
X_test = test.drop('shot_made_flag', axis=1)

# Make pipeline!
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='mean'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1,)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_val)
print('Train Accuracy', pipeline.score(X_train, y_train))
print('Validation Accuracy', accuracy_score(y_val, y_pred))

#
# Out:
# Train Accuracy 1.0
# Validation Accuracy 0.5904037448800468

# %% [markdown]
# ## 6.Get your model's validation accuracy
#
# Done above

# %% [markdown]
# ## 7. Get your model's test accuracy
#
# > (One time, at the end.)

# %%
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='mean'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1,)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
print('Train Accuracy', pipeline.score(X_train, y_train))
print('Test Accuracy', accuracy_score(y_val, y_pred))
# Out:
# Train Accuracy 1.0
# Test Accuracy 0.4909303686366296

# %% [markdown]
# ## 8. Given a confusion matrix, calculate accuracy, precision, and recall.
#
# Imagine this is the confusion matrix for a binary classification model. Use the confusion matrix to calculate the model's accuracy, precision, and recall.
#
# <table>
#   <tr>
#     <td colspan="2" rowspan="2"></td>
#     <td colspan="2">Predicted</td>
#   </tr>
#   <tr>
#     <td>Negative</td>
#     <td>Positive</td>
#   </tr>
#   <tr>
#     <td rowspan="2">Actual</td>
#     <td>Negative</td>
#     <td style="border: solid">85</td>
#     <td style="border: solid">58</td>
#   </tr>
#   <tr>
#     <td>Positive</td>
#     <td style="border: solid">8</td>
#     <td style="border: solid"> 36</td>
#   </tr>
# </table>

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(pipeline, X_val, y_val, values_format='.0f', xticks_rotation='vertical');

# %% [markdown]
# ### Calculate accuracy

# %%
correct_predictions = 628 + 381
correct_predictions
# Out:
# 1009

# %%
total_predictions = 628 + 425 + 381 + 275
total_predictions
# Out:
# 1709

# %%
print('Accuracy: ')
correct_predictions / total_predictions
# Out:
# Accuracy:
# 0.5904037448800468

# %% [markdown]
# ### Calculate precision

# %% [markdown]
# ### Calculate recall

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.70      0.64       903
#            1       0.58      0.47      0.52       806
#
#     accuracy                           0.59      1709
#    macro avg       0.59      0.58      0.58      1709
# weighted avg       0.59      0.59      0.59      1709
